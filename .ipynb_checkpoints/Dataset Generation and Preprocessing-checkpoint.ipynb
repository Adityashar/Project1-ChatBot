# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('data.xlsx', index = False)
data[:5]
# Out:
#    Unique Id    Client Name  Account ID              Legal Entity Currency  \
# 0          1     J P Morgan      101008  CitiBank New York Branch      GBP
# 1          2     J P Morgan      105049  CitiBank New York Branch      USD
# 2          3  DEUTSCHE BANK      105050         CitiBank HongKong      CAD
# 3          4  DEUTSCHE BANK      105058  CitiBank New York Branch      USD
# 4          5  DEUTSCHE BANK      105059  CitiBank New York Branch      EUR
#
#   Payment Type  Paid Amount Payment Date  Payment Status  Pending Amount  \
# 0      Receive        45678   2020-03-11      Fully paid               0
# 1      Receive       765327   2020-03-12  Partially Paid            1008
# 2      Receive       637229   2020-03-13  Partially Paid           34566
# 3      Receive     22345566   2020-03-14  Partially Paid         1000000
# 4      Receive       553322   2020-03-15        Rejected          553322
#
#                      Comments
# 0        Transaction complete
# 1  Waiting for pending amount
# 2  Waiting for pending amount
# 3  Waiting for pending amount
# 4              Payment Failed

# %%
data['Account ID'].describe(), data.shape
# Out:
# (count        20.000000
#  mean     104901.450000
#  std         917.150247
#  min      101008.000000
#  25%      105060.500000
#  50%      105117.500000
#  75%      105128.250000
#  max      105170.000000
#  Name: Account ID, dtype: float64, (20, 11))

# %%
import os

location = '/home/aditya/Documents/Project1-CITI-INTERNSHIP/Data'
files_list = os.listdir(location)
DATASET = data.drop(columns=['Unique Id'], axis = 1)
DATASET['Source'] = "0"
# DATASET.rename(columns={'ClientÂ  Name' : 'ClientName'}, inplace = True)

print(DATASET.columns)

for i, file in enumerate(files_list):
    name = os.path.join(location, file)
    df = pd.read_excel(name, index = False)
    df['Source'] = str(i+1)
    DATASET = pd.concat([DATASET, df], axis = 0, ignore_index=True)
# Out:
# Index(['Client Name', 'Account ID', 'Legal Entity', 'Currency', 'Payment Type',
#        'Paid Amount', 'Payment Date', 'Payment Status', 'Pending Amount',
#        'Comments', 'Source'],
#       dtype='object')

# %%
print(DATASET['Payment Status'].unique(), DATASET['Comments'].unique())
# Out:
# ['Fully paid' 'Partially Paid' 'Rejected' 'Processing'] ['Transaction complete' 'Waiting for pending amount' 'Payment Failed'
#  'Payment is in progress']

# %% [markdown]
# ## Preprocessing
#
# #### 1) Removing redundant ACCOUNT IDs.
# #### 2) Aligning the Payment Status with Paid Amount and Comments.
#
#     I WHEN PAYMENT STATUS = Fully paid, COMMENTS = 'Transaction Complete' & PENDING AMOUNT = 0
#     II WHEN PAYMENT STATUS = Partially Paid, COMMENTS = 'Waiting for pending amount'
#     III WHEN PAYMENT STATUS = Rejected, COMMENTS = 'Payment Failed' & PENDING AMOUNT = PAID AMOUNT
#     IV WHEN PAYMENT STATUS = Processing, COMMENTS = 'TPayment is in progress' & PENDING AMOUNT = PAID AMOUNT
#
# #### 3) Resetting the index

# %%
DATASET.drop_duplicates(['Account ID'], inplace=True)

# FIRST CASE

DATASET.loc[DATASET["Payment Status"] == 'Fully paid', 'Pending Amount'] = 0
DATASET.loc[DATASET["Payment Status"] == 'Fully paid', 'Comments'] = 'Transaction complete'

# SECOND CASE

DATASET.loc[DATASET["Payment Status"] == 'Partially Paid', 'Comments'] = 'Waiting for pending amount'

# THIRD CASE

DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Pending Amount'] = DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Paid Amount']
DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Comments'] = 'Payment Failed'

# FOURTH CASE

DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Pending Amount'] = DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Paid Amount']
DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Comments'] = 'Payment is in progress'

DATASET.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Processing the Date Column
#
# ###### Converting the DATETIME datatype into string for usage later.

# %%
from datetime import datetime

DATASET['Payment Date'][20:] = DATASET['Payment Date'][20:].apply(lambda data : datetime.strptime(str(data), "%Y/%m/%d"))
DATASET['Payment Date'] = DATASET['Payment Date'].apply(lambda data : str(data)[:11])
DATASET['Account ID'] = DATASET['Account ID'].apply(lambda data : str(data)[:11])

type(DATASET['Payment Date'][11])
# Out:
# /home/aditya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# str

# %%
type(DATASET['Source'][24])
# Out:
# str

# %%
DATASET.to_csv('dataset.csv')

# %%
print(DATASET["Client Name"].unique())
print(DATASET["Legal Entity"].unique())
print(DATASET["Currency"].unique())
print(DATASET["Payment Type"].unique())
print(DATASET["Payment Status"].unique())
print(DATASET["Comments"].unique())
# Out:
# ['J P Morgan' 'DEUTSCHE BANK' 'BNY Mellon' 'HSBC' 'Goldman Sachs'
#  'Morgan Stanley' 'Wells Fargo' 'BNP Paribas']
# ['CitiBank New York Branch' 'CitiBank HongKong' 'CitiBank London'
#  'CitiBank Singapore' 'CitiBank Bangaluru' 'CitiBank Pune']
# ['GBP' 'USD' 'CAD' 'EUR' 'INR']
# ['Receive' 'Deliver']
# ['Fully paid' 'Partially Paid' 'Rejected' 'Processing']
# ['Transaction complete' 'Waiting for pending amount' 'Payment Failed'
#  'Payment is in progress']

# %%
type(DATASET['Account ID'][0])
# Out:
# str

# %%
DATASET[20:50]
# Out:
#        Client Name Account ID              Legal Entity Currency Payment Type  \
# 20            HSBC     103560        CitiBank Bangaluru      INR      Receive
# 21      J P Morgan     104644             CitiBank Pune      INR      Receive
# 22   Goldman Sachs     104136           CitiBank London      CAD      Deliver
# 23  Morgan Stanley     103256        CitiBank Bangaluru      USD      Receive
# 24     Wells Fargo     104112        CitiBank Bangaluru      USD      Deliver
# 25  Morgan Stanley     101369  CitiBank New York Branch      GBP      Receive
# 26      BNY Mellon     102729             CitiBank Pune      GBP      Deliver
# 27   Goldman Sachs     103197           CitiBank London      EUR      Receive
# 28   Goldman Sachs     104425        CitiBank Singapore      EUR      Deliver
# 29     Wells Fargo     103600           CitiBank London      USD      Deliver
# 30     Wells Fargo     103640        CitiBank Singapore      GBP      Deliver
# 31     BNP Paribas     101655        CitiBank Bangaluru      EUR      Receive
# 32      J P Morgan     103262             CitiBank Pune      USD      Deliver
# 33            HSBC     102806        CitiBank Singapore      CAD      Deliver
# 34      BNY Mellon     103690           CitiBank London      EUR      Deliver
# 35      J P Morgan     103490        CitiBank Singapore      GBP      Receive
# 36   Goldman Sachs     101418         CitiBank HongKong      GBP      Receive
# 37   Goldman Sachs     104633  CitiBank New York Branch      INR      Deliver
# 38            HSBC     102057           CitiBank London      EUR      Deliver
# 39  Morgan Stanley     101872        CitiBank Singapore      EUR      Receive
# 40     Wells Fargo     103180        CitiBank Bangaluru      EUR      Deliver
# 41   Goldman Sachs     105086             CitiBank Pune      EUR      Receive
# 42      BNY Mellon     102906         CitiBank HongKong      EUR      Receive
# 43      J P Morgan     103946        CitiBank Bangaluru      GBP      Receive
# 44     BNP Paribas     102516         CitiBank HongKong      EUR      Deliver
# 45   Goldman Sachs     101072             CitiBank Pune      EUR      Deliver
# 46            HSBC     105091        CitiBank Bangaluru      CAD      Deliver
# 47      BNY Mellon     104512  CitiBank New York Branch      EUR      Deliver
# 48  Morgan Stanley     103731        CitiBank Bangaluru      USD      Deliver
# 49      BNY Mellon     101071        CitiBank Singapore      EUR      Receive
#
#     Paid Amount Payment Date  Payment Status  Pending Amount  \
# 20         2421  2020-02-23       Fully paid               0
# 21         6879  2020-02-26       Processing            6879
# 22         6633  2020-02-24   Partially Paid            5987
# 23         7332  2020-04-28       Processing            7332
# 24          484  2020-04-20   Partially Paid            6030
# 25         7332  2020-04-17       Fully paid               0
# 26         1667  2020-04-07   Partially Paid            9533
# 27          622  2020-05-21       Fully paid               0
# 28         1778  2020-04-11       Fully paid               0
# 29         5374  2020-05-05       Fully paid               0
# 30         5393  2020-05-14         Rejected            5393
# 31         5255  2020-05-09   Partially Paid            6822
# 32         8154  2020-05-22         Rejected            8154
# 33         7899  2020-03-12         Rejected            7899
# 34         8605  2020-03-11       Fully paid               0
# 35          419  2020-06-02       Processing             419
# 36         4442  2020-03-12       Processing            4442
# 37         7020  2020-06-01       Fully paid               0
# 38         2580  2020-02-20   Partially Paid            9071
# 39         5132  2020-02-22       Fully paid               0
# 40         9679  2020-05-23         Rejected            9679
# 41         8632  2020-03-14       Processing            8632
# 42         2029  2020-05-11         Rejected            2029
# 43         5393  2020-05-20         Rejected            5393
# 44         5483  2020-03-08         Rejected            5483
# 45         5369  2020-03-15   Partially Paid            7436
# 46          854  2020-04-19       Fully paid               0
# 47         8358  2020-05-14   Partially Paid            2059
# 48         1297  2020-04-02         Rejected            1297
# 49         2076  2020-03-06         Rejected            2076
#
#                       Comments Source
# 20        Transaction complete      1
# 21      Payment is in progress      1
# 22  Waiting for pending amount      1
# 23      Payment is in progress      1
# 24  Waiting for pending amount      1
# 25        Transaction complete      1
# 26  Waiting for pending amount      1
# 27        Transaction complete      1
# 28        Transaction complete      1
# 29        Transaction complete      1
# 30              Payment Failed      1
# 31  Waiting for pending amount      1
# 32              Payment Failed      1
# 33              Payment Failed      1
# 34        Transaction complete      1
# 35      Payment is in progress      1
# 36      Payment is in progress      1
# 37        Transaction complete      1
# 38  Waiting for pending amount      1
# 39        Transaction complete      1
# 40              Payment Failed      1
# 41      Payment is in progress      1
# 42              Payment Failed      1
# 43              Payment Failed      1
# 44              Payment Failed      1
# 45  Waiting for pending amount      1
# 46        Transaction complete      1
# 47  Waiting for pending amount      1
# 48              Payment Failed      1
# 49              Payment Failed      1

# %%
questions1 = pd.read_pickle('/home/aditya/Downloads/questions.pkl')
questions2 = pd.read_pickle('/home/aditya/Downloads/q3.pkl')
solutions1 = pd.read_pickle('/home/aditya/Downloads/solution.pkl')
solutions2 = pd.read_pickle('/home/aditya/Downloads/s3.pkl')

# %%
questions1 = questions1.tolist()
questions = questions1 + questions2

# %%
from sklearn.feature_extraction.text import CountVectorizer
CV = CountVectorizer(ngram_range=(1,1))

vec = CV.fit_transform(questions)

CV.vocabulary_

vec.shape
# Out:
# (19000, 2000)

# %%
pd.to_pickle(vec, "/home/aditya/Documents/Project1-CITI-INTERNSHIP/vec.pkl")
pd.to_pickle(vec, "/home/aditya/Documents/Project1-CITI-INTERNSHIP/dict.pkl")
