# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('data.xlsx', index = False)
data[:5]
# Out:
#    Unique Id    Client Name  Account ID              Legal Entity Currency  \
# 0          1     J P Morgan      101008  CitiBank New York Branch      GBP
# 1          2     J P Morgan      105049  CitiBank New York Branch      USD
# 2          3  DEUTSCHE BANK      105050         CitiBank HongKong      CAD
# 3          4  DEUTSCHE BANK      105058  CitiBank New York Branch      USD
# 4          5  DEUTSCHE BANK      105059  CitiBank New York Branch      EUR
#
#   Payment Type  Paid Amount Payment Date  Payment Status  Pending Amount  \
# 0      Receive        45678   2020-03-11      Fully paid               0
# 1      Receive       765327   2020-03-12  Partially Paid            1008
# 2      Receive       637229   2020-03-13  Partially Paid           34566
# 3      Receive     22345566   2020-03-14  Partially Paid         1000000
# 4      Receive       553322   2020-03-15        Rejected          553322
#
#                      Comments
# 0        Transaction complete
# 1  Waiting for pending amount
# 2  Waiting for pending amount
# 3  Waiting for pending amount
# 4              Payment Failed

# %%
data['Account ID'].describe(), data.shape
# Out:
# (count        20.000000
#  mean     104901.450000
#  std         917.150247
#  min      101008.000000
#  25%      105060.500000
#  50%      105117.500000
#  75%      105128.250000
#  max      105170.000000
#  Name: Account ID, dtype: float64, (20, 11))

# %%
import os

location = '/home/aditya/Documents/Project1-CITI-INTERNSHIP/Data'
files_list = os.listdir(location)
DATASET = data.drop(columns=['Unique Id'], axis = 1)
# DATASET.rename(columns={'ClientÂ  Name' : 'ClientName'}, inplace = True)

print(DATASET.columns)

for file in files_list:
    name = os.path.join(location, file)
    df = pd.read_excel(name, index = False)
    DATASET = pd.concat([DATASET, df], axis = 0, ignore_index=True)
# Out:
# Index(['Client Name', 'Account ID', 'Legal Entity', 'Currency', 'Payment Type',
#        'Paid Amount', 'Payment Date', 'Payment Status', 'Pending Amount',
#        'Comments'],
#       dtype='object')

# %%
print(DATASET['Payment Status'].unique(), DATASET['Comments'].unique())
# Out:
# ['Fully paid' 'Partially Paid' 'Rejected' 'Processing'] ['Transaction complete' 'Waiting for pending amount' 'Payment Failed'
#  'Payment is in progress']

# %% [markdown]
# ## Preprocessing
#
# #### 1) Removing redundant ACCOUNT IDs.
# #### 2) Aligning the Payment Status with Paid Amount and Comments.
#
#     I WHEN PAYMENT STATUS = Fully paid, COMMENTS = 'Transaction Complete' & PENDING AMOUNT = 0
#     II WHEN PAYMENT STATUS = Partially Paid, COMMENTS = 'Waiting for pending amount'
#     III WHEN PAYMENT STATUS = Rejected, COMMENTS = 'Payment Failed' & PENDING AMOUNT = PAID AMOUNT
#     IV WHEN PAYMENT STATUS = Processing, COMMENTS = 'TPayment is in progress' & PENDING AMOUNT = PAID AMOUNT
#
# #### 3) Resetting the index

# %%
DATASET.drop_duplicates(['Account ID'], inplace=True)

# FIRST CASE

DATASET.loc[DATASET["Payment Status"] == 'Fully paid', 'Pending Amount'] = 0
DATASET.loc[DATASET["Payment Status"] == 'Fully paid', 'Comments'] = 'Transaction complete'

# SECOND CASE

DATASET.loc[DATASET["Payment Status"] == 'Partially Paid', 'Comments'] = 'Waiting for pending amount'

# THIRD CASE

DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Pending Amount'] = DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Paid Amount']
DATASET.loc[DATASET["Payment Status"] == 'Rejected', 'Comments'] = 'Payment Failed'

# FOURTH CASE

DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Pending Amount'] = DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Paid Amount']
DATASET.loc[DATASET["Payment Status"] == 'Processing', 'Comments'] = 'Payment is in progress'

DATASET.reset_index(drop=True, inplace=True)

# %%
DATASET
# Out:
#         Client Name  Account ID              Legal Entity Currency  \
# 0        J P Morgan      101008  CitiBank New York Branch      GBP
# 1        J P Morgan      105049  CitiBank New York Branch      USD
# 2     DEUTSCHE BANK      105050         CitiBank HongKong      CAD
# 3     DEUTSCHE BANK      105058  CitiBank New York Branch      USD
# 4     DEUTSCHE BANK      105059  CitiBank New York Branch      EUR
# 5        BNY Mellon      105061           CitiBank London      USD
# 6        BNY Mellon      105071           CitiBank London      GBP
# 7        BNY Mellon      105101           CitiBank London      EUR
# 8        BNY Mellon      105102  CitiBank New York Branch      USD
# 9        J P Morgan      105115        CitiBank Singapore      EUR
# 10       J P Morgan      105126  CitiBank New York Branch      USD
# 11    DEUTSCHE BANK      105120  CitiBank New York Branch      EUR
# 12    DEUTSCHE BANK      105121           CitiBank London      USD
# 13    DEUTSCHE BANK      105122           CitiBank London      GBP
# 14       BNY Mellon      105125  CitiBank New York Branch      EUR
# 15       BNY Mellon      105135           CitiBank London      USD
# 16       BNY Mellon      105140           CitiBank London      EUR
# 17       BNY Mellon      105146        CitiBank Singapore      USD
# 18             HSBC      105150  CitiBank New York Branch      GBP
# 19             HSBC      105170        CitiBank Singapore      EUR
# 20             HSBC      103560        CitiBank Bangaluru      INR
# 21       J P Morgan      104644             CitiBank Pune      INR
# 22    Goldman Sachs      104136           CitiBank London      CAD
# 23   Morgan Stanley      103256        CitiBank Bangaluru      USD
# 24      Wells Fargo      104112        CitiBank Bangaluru      USD
# 25   Morgan Stanley      101369  CitiBank New York Branch      GBP
# 26       BNY Mellon      102729             CitiBank Pune      GBP
# 27    Goldman Sachs      103197           CitiBank London      EUR
# 28    Goldman Sachs      104425        CitiBank Singapore      EUR
# 29      Wells Fargo      103600           CitiBank London      USD
# ..              ...         ...                       ...      ...
# 890  Morgan Stanley      102867         CitiBank HongKong      EUR
# 891     BNP Paribas      104764  CitiBank New York Branch      INR
# 892     BNP Paribas      102448        CitiBank Bangaluru      GBP
# 893      BNY Mellon      101845         CitiBank HongKong      EUR
# 894   Goldman Sachs      102020         CitiBank HongKong      INR
# 895     BNP Paribas      103012         CitiBank HongKong      USD
# 896   Goldman Sachs      101900  CitiBank New York Branch      GBP
# 897            HSBC      102738           CitiBank London      USD
# 898   Goldman Sachs      104994        CitiBank Singapore      INR
# 899   Goldman Sachs      101591        CitiBank Bangaluru      EUR
# 900      J P Morgan      102382  CitiBank New York Branch      CAD
# 901     BNP Paribas      101704  CitiBank New York Branch      USD
# 902      BNY Mellon      105127             CitiBank Pune      INR
# 903      J P Morgan      101098  CitiBank New York Branch      CAD
# 904      J P Morgan      104934           CitiBank London      CAD
# 905      BNY Mellon      102042         CitiBank HongKong      CAD
# 906      J P Morgan      104328  CitiBank New York Branch      EUR
# 907   DEUTSCHE BANK      103513         CitiBank HongKong      USD
# 908   DEUTSCHE BANK      104169        CitiBank Bangaluru      CAD
# 909            HSBC      104968           CitiBank London      GBP
# 910      J P Morgan      104132         CitiBank HongKong      USD
# 911   DEUTSCHE BANK      102255             CitiBank Pune      EUR
# 912   DEUTSCHE BANK      101946        CitiBank Bangaluru      INR
# 913            HSBC      101485        CitiBank Singapore      INR
# 914   Goldman Sachs      103875        CitiBank Bangaluru      CAD
# 915      J P Morgan      102529        CitiBank Bangaluru      INR
# 916      BNY Mellon      101013        CitiBank Singapore      GBP
# 917   DEUTSCHE BANK      102771           CitiBank London      CAD
# 918   Goldman Sachs      102400        CitiBank Singapore      EUR
# 919   Goldman Sachs      104914  CitiBank New York Branch      INR
#
#     Payment Type  Paid Amount         Payment Date  Payment Status  \
# 0        Receive        45678  2020-03-11 00:00:00      Fully paid
# 1        Receive       765327  2020-03-12 00:00:00  Partially Paid
# 2        Receive       637229  2020-03-13 00:00:00  Partially Paid
# 3        Receive     22345566  2020-03-14 00:00:00  Partially Paid
# 4        Receive       553322  2020-03-15 00:00:00        Rejected
# 5        Receive        56789  2020-03-16 00:00:00        Rejected
# 6        Receive     98735627  2020-03-07 00:00:00        Rejected
# 7        Receive         6578  2020-03-08 00:00:00      Fully paid
# 8        Receive       352627  2020-03-09 00:00:00  Partially Paid
# 9        Receive       532828  2020-03-10 00:00:00      Fully paid
# 10       Deliver         4567  2020-04-11 00:00:00      Fully paid
# 11       Deliver        87643  2020-03-12 00:00:00      Processing
# 12       Deliver        22345  2020-03-13 00:00:00      Fully paid
# 13       Deliver        55543  2020-03-14 00:00:00      Fully paid
# 14       Deliver        23455  2020-06-01 00:00:00        Rejected
# 15       Deliver      4321456  2020-03-16 00:00:00      Processing
# 16       Deliver       654322  2020-03-17 00:00:00      Processing
# 17       Deliver       876543  2020-06-10 00:00:00      Processing
# 18       Deliver         3456  2020-03-19 00:00:00      Processing
# 19       Deliver         6664  2020-03-20 00:00:00      Processing
# 20       Receive         2421           2020/02/23      Fully paid
# 21       Receive         6879           2020/02/26      Processing
# 22       Deliver         6633           2020/02/24  Partially Paid
# 23       Receive         7332           2020/04/28      Processing
# 24       Deliver          484           2020/04/20  Partially Paid
# 25       Receive         7332           2020/04/17      Fully paid
# 26       Deliver         1667           2020/04/07  Partially Paid
# 27       Receive          622           2020/05/21      Fully paid
# 28       Deliver         1778           2020/04/11      Fully paid
# 29       Deliver         5374           2020/05/05      Fully paid
# ..           ...          ...                  ...             ...
# 890      Deliver         4073           2020/05/23  Partially Paid
# 891      Deliver         2742           2020/03/03      Fully paid
# 892      Receive         8134           2020/05/28        Rejected
# 893      Receive         2461           2020/04/18  Partially Paid
# 894      Receive         7000           2020/05/11      Fully paid
# 895      Receive         6123           2020/06/07        Rejected
# 896      Deliver         9640           2020/02/23      Processing
# 897      Deliver         2281           2020/02/29        Rejected
# 898      Receive         1007           2020/05/13  Partially Paid
# 899      Receive         9008           2020/02/25        Rejected
# 900      Receive         2734           2020/03/16      Processing
# 901      Receive         2770           2020/05/17        Rejected
# 902      Receive         1347           2020/04/15  Partially Paid
# 903      Receive          550           2020/05/23      Processing
# 904      Deliver          817           2020/02/26        Rejected
# 905      Deliver         6143           2020/03/11      Processing
# 906      Deliver          312           2020/03/16      Fully paid
# 907      Receive         2040           2020/05/12      Processing
# 908      Receive         6834           2020/03/27  Partially Paid
# 909      Deliver         5398           2020/03/10      Processing
# 910      Receive         5229           2020/05/21  Partially Paid
# 911      Deliver         6941           2020/03/14      Fully paid
# 912      Receive         7347           2020/05/11      Processing
# 913      Deliver         2376           2020/05/24  Partially Paid
# 914      Deliver         3547           2020/06/02        Rejected
# 915      Receive           36           2020/05/27        Rejected
# 916      Deliver         4967           2020/02/21      Processing
# 917      Receive         5781           2020/05/11        Rejected
# 918      Receive         6353           2020/04/25      Fully paid
# 919      Deliver         7683           2020/04/30      Processing
#
#      Pending Amount                    Comments
# 0                 0        Transaction complete
# 1              1008  Waiting for pending amount
# 2             34566  Waiting for pending amount
# 3           1000000  Waiting for pending amount
# 4            553322              Payment Failed
# 5             56789              Payment Failed
# 6          98735627              Payment Failed
# 7                 0        Transaction complete
# 8             23456  Waiting for pending amount
# 9                 0        Transaction complete
# 10                0        Transaction complete
# 11            87643      Payment is in progress
# 12                0        Transaction complete
# 13                0        Transaction complete
# 14            23455              Payment Failed
# 15          4321456      Payment is in progress
# 16           654322      Payment is in progress
# 17           876543      Payment is in progress
# 18             3456      Payment is in progress
# 19             6664      Payment is in progress
# 20                0        Transaction complete
# 21             6879      Payment is in progress
# 22             5987  Waiting for pending amount
# 23             7332      Payment is in progress
# 24             6030  Waiting for pending amount
# 25                0        Transaction complete
# 26             9533  Waiting for pending amount
# 27                0        Transaction complete
# 28                0        Transaction complete
# 29                0        Transaction complete
# ..              ...                         ...
# 890             243  Waiting for pending amount
# 891               0        Transaction complete
# 892            8134              Payment Failed
# 893            1943  Waiting for pending amount
# 894               0        Transaction complete
# 895            6123              Payment Failed
# 896            9640      Payment is in progress
# 897            2281              Payment Failed
# 898            7009  Waiting for pending amount
# 899            9008              Payment Failed
# 900            2734      Payment is in progress
# 901            2770              Payment Failed
# 902            8237  Waiting for pending amount
# 903             550      Payment is in progress
# 904             817              Payment Failed
# 905            6143      Payment is in progress
# 906               0        Transaction complete
# 907            2040      Payment is in progress
# 908            1611  Waiting for pending amount
# 909            5398      Payment is in progress
# 910            3595  Waiting for pending amount
# 911               0        Transaction complete
# 912            7347      Payment is in progress
# 913            8877  Waiting for pending amount
# 914            3547              Payment Failed
# 915              36              Payment Failed
# 916            4967      Payment is in progress
# 917            5781              Payment Failed
# 918               0        Transaction complete
# 919            7683      Payment is in progress
#
# [920 rows x 10 columns]

# %% [markdown]
# ### Processing the Date Column
#
# ###### Converting the DATETIME datatype into string for usage later.

# %%
from datetime import datetime

DATASET['Payment Date'][20:] = DATASET['Payment Date'][20:].apply(lambda data : datetime.strptime(str(data), "%Y/%m/%d"))
DATASET['Payment Date'] = DATASET['Payment Date'].apply(lambda data : str(data)[:11])

type(DATASET['Payment Date'][11])
# Out:
# /home/aditya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# str

# %%
DATASET.to_csv('dataset.csv')

# %%
questions1 = pd.read_pickle('/home/aditya/Downloads/questions.pkl')
questions2 = pd.read_pickle('/home/aditya/Downloads/q3.pkl')
solutions1 = pd.read_pickle('/home/aditya/Downloads/solution.pkl')
solutions2 = pd.read_pickle('/home/aditya/Downloads/s3.pkl')

# %%
questions1 = questions1.tolist()
questions = questions1 + questions2

# %%
from sklearn.feature_extraction.text import CountVectorizer
CV = CountVectorizer(ngram_range=(1,3))

vec = CV.fit_transform(questions)

CV.vocabulary_
# Out:
# {'who': 10519,
#  'is': 7875,
#  'the': 8437,
#  'client': 6720,
#  'with': 10525,
#  'account': 4520,
#  'id': 6938,
#  '101008': 326,
#  'who is': 10520,
#  'is the': 7878,
#  'the client': 8444,
#  'client with': 6721,
#  'with account': 10526,
#  'account id': 4521,
#  'id 101008': 6939,
#  'who is the': 10521,
#  'is the client': 7879,
#  'the client with': 8445,
#  'client with account': 6722,
#  'with account id': 10527,
#  'account id 101008': 4522,
#  '105049': 1213,
#  'id 105049': 7814,
#  'account id 105049': 5397,
#  '105050': 1214,
#  'id 105050': 7815,
#  'account id 105050': 5398,
#  '105058': 1219,
#  'id 105058': 7820,
#  'account id 105058': 5403,
#  '105059': 1220,
#  'id 105059': 7821,
#  'account id 105059': 5404,
#  '105061': 1221,
#  'id 105061': 7822,
#  'account id 105061': 5405,
#  '105071': 1223,
#  'id 105071': 7824,
#  'account id 105071': 5407,
#  '105101': 1237,
#  'id 105101': 7838,
#  'account id 105101': 5421,
#  '105102': 1238,
#  'id 105102': 7839,
#  'account id 105102': 5422,
#  '105115': 1241,
#  'id 105115': 7842,
#  'account id 105115': 5425,
#  '105126': 1247,
#  'id 105126': 7848,
#  'account id 105126': 5431,
#  '105120': 1243,
#  'id 105120': 7844,
#  'account id 105120': 5427,
#  '105121': 1244,
#  'id 105121': 7845,
#  'account id 105121': 5428,
#  '105122': 1245,
#  'id 105122': 7846,
#  'account id 105122': 5429,
#  '105125': 1246,
#  'id 105125': 7847,
#  'account id 105125': 5430,
#  '105135': 1250,
#  'id 105135': 7851,
#  'account id 105135': 5434,
#  '105140': 1252,
#  'id 105140': 7853,
#  'account id 105140': 5436,
#  '105146': 1253,
#  'id 105146': 7854,
#  'account id 105146': 5437,
#  '105150': 1255,
#  'id 105150': 7856,
#  'account id 105150': 5439,
#  '105170': 1257,
#  'id 105170': 7858,
#  'account id 105170': 5441,
#  '103443': 880,
#  'id 103443': 7493,
#  'account id 103443': 5076,
#  '102387': 638,
#  'id 102387': 7251,
#  'account id 102387': 4834,
#  '104466': 1080,
#  'id 104466': 7684,
#  'account id 104466': 5267,
#  '101686': 479,
#  'id 101686': 7092,
#  'account id 101686': 4675,
#  '104461': 1079,
#  'id 104461': 7683,
#  'account id 104461': 5266,
#  '104768': 1152,
#  'id 104768': 7756,
#  'account id 104768': 5339,
#  '103354': 867,
#  'id 103354': 7480,
#  'account id 103354': 5063,
#  '101680': 477,
#  'id 101680': 7090,
#  'account id 101680': 4673,
#  '101568': 455,
#  'id 101568': 7068,
#  'account id 101568': 4651,
#  '103705': 929,
#  'id 103705': 7542,
#  'account id 103705': 5125,
#  '102454': 663,
#  'id 102454': 7276,
#  'account id 102454': 4859,
#  '102803': 745,
#  'id 102803': 7358,
#  'account id 102803': 4941,
#  '101677': 475,
#  'id 101677': 7088,
#  'account id 101677': 4671,
#  '104133': 1019,
#  'id 104133': 7623,
#  'account id 104133': 5206,
#  '101926': 531,
#  'id 101926': 7144,
#  'account id 101926': 4727,
#  '104007': 1000,
#  'id 104007': 7604,
#  'account id 104007': 5187,
#  '101860': 520,
#  'id 101860': 7133,
#  'account id 101860': 4716,
#  '105095': 1235,
#  'id 105095': 7836,
#  'account id 105095': 5419,
#  '102032': 553,
#  'id 102032': 7166,
#  'account id 102032': 4749,
#  '103723': 934,
#  'id 103723': 7547,
#  'account id 103723': 5130,
#  '102509': 675,
#  'id 102509': 7288,
#  'account id 102509': 4871,
#  '102437': 658,
#  'id 102437': 7271,
#  'account id 102437': 4854,
#  '103255': 849,
#  'id 103255': 7462,
#  'account id 103255': 5045,
#  '104564': 1102,
#  'id 104564': 7706,
#  'account id 104564': 5289,
#  '102691': 722,
#  'id 102691': 7335,
#  'account id 102691': 4918,
#  '101602': 461,
#  'id 101602': 7074,
#  'account id 101602': 4657,
#  '101738': 496,
#  'id 101738': 7109,
#  'account id 101738': 4692,
#  '103699': 926,
#  'id 103699': 7539,
#  'account id 103699': 5122,
#  '101472': 429,
#  'id 101472': 7042,
#  'account id 101472': 4625,
#  '102956': 775,
#  'id 102956': 7388,
#  'account id 102956': 4971,
#  '104795': 1158,
#  'id 104795': 7762,
#  'account id 104795': 5345,
#  '101726': 492,
#  'id 101726': 7105,
#  'account id 101726': 4688,
#  '101161': 356,
#  'id 101161': 6969,
#  'account id 101161': 4552,
#  '104424': 1072,
#  'id 104424': 7676,
#  'account id 104424': 5259,
#  '101371': 403,
#  'id 101371': 7016,
#  'account id 101371': 4599,
#  '102428': 654,
#  'id 102428': 7267,
#  'account id 102428': 4850,
#  '105090': 1233,
#  'id 105090': 7834,
#  'account id 105090': 5417,
#  '104957': 1195,
#  'id 104957': 7796,
#  'account id 104957': 5379,
#  '104374': 1061,
#  'id 104374': 7665,
#  'account id 104374': 5248,
#  '103449': 882,
#  'id 103449': 7495,
#  'account id 103449': 5078,
#  '103954': 987,
#  'id 103954': 7597,
#  'account id 103954': 5180,
#  '102347': 628,
#  'id 102347': 7241,
#  'account id 102347': 4824,
#  '103766': 944,
#  'id 103766': 7557,
#  'account id 103766': 5140,
#  '102507': 674,
#  'id 102507': 7287,
#  'account id 102507': 4870,
#  '105026': 1210,
#  'id 105026': 7811,
#  'account id 105026': 5394,
#  '104875': 1177,
#  'id 104875': 7778,
#  'account id 104875': 5361,
#  '102052': 561,
#  'id 102052': 7174,
#  'account id 102052': 4757,
#  '101072': 337,
#  'id 101072': 6950,
#  'account id 101072': 4533,
#  '101353': 394,
#  'id 101353': 7007,
#  'account id 101353': 4590,
#  '102088': 570,
#  'id 102088': 7183,
#  'account id 102088': 4766,
#  '101807': 511,
#  'id 101807': 7124,
#  'account id 101807': 4707,
#  '102375': 633,
#  'id 102375': 7246,
#  'account id 102375': 4829,
#  '103952': 986,
#  'id 103952': 7596,
#  'account id 103952': 5179,
#  '103989': 989,
#  'id 103989': 7599,
#  'account id 103989': 5182,
#  '101846': 516,
#  'id 101846': 7129,
#  'account id 101846': 4712,
#  '102503': 672,
#  'id 102503': 7285,
#  'account id 102503': 4868,
#  '103466': 884,
#  'id 103466': 7497,
#  'account id 103466': 5080,
#  '104230': 1034,
#  'id 104230': 7638,
#  'account id 104230': 5221,
#  '104602': 1114,
#  'id 104602': 7718,
#  'account id 104602': 5301,
#  '101917': 529,
#  'id 101917': 7142,
#  'account id 101917': 4725,
#  '103821': 961,
#  'id 103821': 7571,
#  'account id 103821': 5154,
#  '102145': 584,
#  'id 102145': 7197,
#  'account id 102145': 4780,
#  '104433': 1076,
#  'id 104433': 7680,
#  'account id 104433': 5263,
#  '103425': 877,
#  'id 103425': 7490,
#  'account id 103425': 5073,
#  '104907': 1183,
#  'id 104907': 7784,
#  'account id 104907': 5367,
#  '102794': 743,
#  'id 102794': 7356,
#  'account id 102794': 4939,
#  '102380': 634,
#  'id 102380': 7247,
#  'account id 102380': 4830,
#  '102303': 614,
#  'id 102303': 7227,
#  'account id 102303': 4810,
#  '105084': 1230,
#  'id 105084': 7831,
#  'account id 105084': 5414,
#  '101114': 346,
#  'id 101114': 6959,
#  'account id 101114': 4542,
#  '104013': 1001,
#  'id 104013': 7605,
#  'account id 104013': 5188,
#  '102253': 607,
#  'id 102253': 7220,
#  'account id 102253': 4803,
#  '101656': 473,
#  'id 101656': 7086,
#  'account id 101656': 4669,
#  '102884': 763,
#  'id 102884': 7376,
#  'account id 102884': 4959,
#  '103922': 977,
#  'id 103922': 7587,
#  'account id 103922': 5170,
#  '101305': 387,
#  'id 101305': 7000,
#  'account id 101305': 4583,
#  '101385': 408,
#  'id 101385': 7021,
#  'account id 101385': 4604,
#  '101778': 501,
#  'id 101778': 7114,
#  'account id 101778': 4697,
#  '103188': 831,
#  'id 103188': 7444,
#  'account id 103188': 5027,
#  '102265': 610,
#  'id 102265': 7223,
#  'account id 102265': 4806,
#  '104649': 1126,
#  'id 104649': 7730,
#  'account id 104649': 5313,
#  '104348': 1056,
#  'id 104348': 7660,
#  'account id 104348': 5243,
#  '103011': 789,
#  'id 103011': 7402,
#  'account id 103011': 4985,
#  '102318': 622,
#  'id 102318': 7235,
#  'account id 102318': 4818,
#  '101639': 468,
#  'id 101639': 7081,
#  'account id 101639': 4664,
#  '101697': 482,
#  'id 101697': 7095,
#  'account id 101697': 4678,
#  '102879': 762,
#  'id 102879': 7375,
#  'account id 102879': 4958,
#  '105057': 1218,
#  'id 105057': 7819,
#  'account id 105057': 5402,
#  '101544': 448,
#  'id 101544': 7061,
#  'account id 101544': 4644,
#  '104528': 1094,
#  'id 104528': 7698,
#  'account id 104528': 5281,
#  '105045': 1212,
#  'id 105045': 7813,
#  'account id 105045': 5396,
#  '104253': 1041,
#  'id 104253': 7645,
#  'account id 104253': 5228,
#  '104139': 1021,
#  'id 104139': 7625,
#  'account id 104139': 5208,
#  '101265': 377,
#  'id 101265': 6990,
#  'account id 101265': 4573,
#  '104155': 1023,
#  'id 104155': 7627,
#  'account id 104155': 5210,
#  '102728': 729,
#  'id 102728': 7342,
#  'account id 102728': 4925,
#  '102586': 694,
#  'id 102586': 7307,
#  'account id 102586': 4890,
#  '103495': 889,
#  'id 103495': 7502,
#  'account id 103495': 5085,
#  '102750': 736,
#  'id 102750': 7349,
#  'account id 102750': 4932,
#  '104126': 1016,
#  'id 104126': 7620,
#  'account id 104126': 5203,
#  '102457': 664,
#  'id 102457': 7277,
#  'account id 102457': 4860,
#  '102101': 573,
#  'id 102101': 7186,
#  'account id 102101': 4769,
#  '103996': 992,
#  'id 103996': 7602,
#  'account id 103996': 5185,
#  '102061': 564,
#  'id 102061': 7177,
#  'account id 102061': 4760,
#  '103759': 942,
#  'id 103759': 7555,
#  'account id 103759': 5138,
#  '101507': 439,
#  'id 101507': 7052,
#  'account id 101507': 4635,
#  '103110': 812,
#  'id 103110': 7425,
#  'account id 103110': 5008,
#  '102167': 590,
#  'id 102167': 7203,
#  'account id 102167': 4786,
#  '103073': 800,
#  'id 103073': 7413,
#  'account id 103073': 4996,
#  '104753': 1148,
#  'id 104753': 7752,
#  'account id 104753': 5335,
#  '101555': 453,
#  'id 101555': 7066,
#  'account id 101555': 4649,
#  '103896': 970,
#  'id 103896': 7580,
#  'account id 103896': 5163,
#  '101710': 487,
#  'id 101710': 7100,
#  'account id 101710': 4683,
#  '103231': 841,
#  'id 103231': 7454,
#  'account id 103231': 5037,
#  '102117': 578,
#  'id 102117': 7191,
#  'account id 102117': 4774,
#  '102308': 615,
#  'id 102308': 7228,
#  'account id 102308': 4811,
#  '101630': 467,
#  'id 101630': 7080,
#  'account id 101630': 4663,
#  '102737': 732,
#  'id 102737': 7345,
#  'account id 102737': 4928,
#  '102580': 691,
#  'id 102580': 7304,
#  'account id 102580': 4887,
#  '101687': 480,
#  'id 101687': 7093,
#  'account id 101687': 4676,
#  '103026': 793,
#  'id 103026': 7406,
#  'account id 103026': 4989,
#  '102859': 756,
#  'id 102859': 7369,
#  'account id 102859': 4952,
#  '104592': 1111,
#  'id 104592': 7715,
#  'account id 104592': 5298,
#  '102825': 750,
#  'id 102825': 7363,
#  'account id 102825': 4946,
#  '101733': 495,
#  'id 101733': 7108,
#  'account id 101733': 4691,
#  '103237': 844,
#  'id 103237': 7457,
#  'account id 103237': 5040,
#  '105076': 1226,
#  'id 105076': 7827,
#  'account id 105076': 5410,
#  '104250': 1040,
#  'id 104250': 7644,
#  'account id 104250': 5227,
#  '103124': 818,
#  'id 103124': 7431,
#  'account id 103124': 5014,
#  '101373': 404,
#  'id 101373': 7017,
#  'account id 101373': 4600,
#  '104804': 1164,
#  'id 104804': 7765,
#  'account id 104804': 5348,
#  '101678': 476,
#  'id 101678': 7089,
#  'account id 101678': 4672,
#  '103087': 804,
#  'id 103087': 7417,
#  'account id 103087': 5000,
#  '102981': 784,
#  'id 102981': 7397,
#  'account id 102981': 4980,
#  '104123': 1015,
#  'id 104123': 7619,
#  'account id 104123': 5202,
#  '103069': 799,
#  'id 103069': 7412,
#  'account id 103069': 4995,
#  '102610': 700,
#  'id 102610': 7313,
#  'account id 102610': 4896,
#  '101626': 466,
#  'id 101626': 7079,
#  'account id 101626': 4662,
#  '104720': 1138,
#  'id 104720': 7742,
#  'account id 104720': 5325,
#  '102997': 786,
#  'id 102997': 7399,
#  'account id 102997': 4982,
#  '104952': 1193,
#  'id 104952': 7794,
#  'account id 104952': 5377,
#  '104628': 1121,
#  'id 104628': 7725,
#  'account id 104628': 5308,
#  '104393': 1066,
#  'id 104393': 7670,
#  'account id 104393': 5253,
#  '101197': 365,
#  'id 101197': 6978,
#  'account id 101197': 4561,
#  '101673': 474,
#  'id 101673': 7087,
#  'account id 101673': 4670,
#  '103248': 847,
#  'id 103248': 7460,
#  'account id 103248': 5043,
#  '103503': 893,
#  'id 103503': 7506,
#  'account id 103503': 5089,
#  '101368': 400,
#  'id 101368': 7013,
#  'account id 101368': 4596,
#  '102689': 720,
#  'id 102689': 7333,
#  'account id 102689': 4916,
#  '102002': 545,
#  'id 102002': 7158,
#  'account id 102002': 4741,
#  '102649': 712,
#  'id 102649': 7325,
#  'account id 102649': 4908,
#  '101753': 497,
#  'id 101753': 7110,
#  'account id 101753': 4693,
#  '101530': 444,
#  'id 101530': 7057,
#  'account id 101530': 4640,
#  '102075': 567,
#  'id 102075': 7180,
#  'account id 102075': 4763,
#  '101569': 456,
#  'id 101569': 7069,
#  'account id 101569': 4652,
#  '102018': 549,
#  'id 102018': 7162,
#  'account id 102018': 4745,
#  '102386': 637,
#  'id 102386': 7250,
#  'account id 102386': 4833,
#  '102316': 621,
#  'id 102316': 7234,
#  'account id 102316': 4817,
#  '102819': 749,
#  'id 102819': 7362,
#  'account id 102819': 4945,
#  '104872': 1176,
#  'id 104872': 7777,
#  'account id 104872': 5360,
#  '101474': 430,
#  'id 101474': 7043,
#  'account id 101474': 4626,
#  '102182': 595,
#  'id 102182': 7208,
#  'account id 102182': 4791,
#  '104944': 1191,
#  'id 104944': 7792,
#  'account id 104944': 5375,
#  '101589': 459,
#  'id 101589': 7072,
#  'account id 101589': 4655,
#  '102415': 650,
#  'id 102415': 7263,
#  'account id 102415': 4846,
#  '101968': 539,
#  'id 101968': 7152,
#  'account id 101968': 4735,
#  '101239': 372,
#  'id 101239': 6985,
#  'account id 101239': 4568,
#  '105012': 1207,
#  'id 105012': 7808,
#  'account id 105012': 5391,
#  '103184': 829,
#  'id 103184': 7442,
#  'account id 103184': 5025,
#  '104460': 1078,
#  'id 104460': 7682,
#  'account id 104460': 5265,
#  '102585': 693,
#  'id 102585': 7306,
#  'account id 102585': 4889,
#  '101424': 418,
#  'id 101424': 7031,
#  'account id 101424': 4614,
#  '101769': 500,
#  'id 101769': 7113,
#  'account id 101769': 4696,
#  '101080': 339,
#  'id 101080': 6952,
#  'account id 101080': 4535,
#  '103112': 814,
#  'id 103112': 7427,
#  'account id 103112': 5010,
#  '102012': 548,
#  'id 102012': 7161,
#  'account id 102012': 4744,
#  '102846': 751,
#  'id 102846': 7364,
#  'account id 102846': 4947,
#  '101864': 521,
#  'id 101864': 7134,
#  'account id 101864': 4717,
#  '102402': 645,
#  'id 102402': 7258,
#  'account id 102402': 4841,
#  '101517': 442,
#  'id 101517': 7055,
#  'account id 101517': 4638,
#  '101761': 499,
#  'id 101761': 7112,
#  'account id 101761': 4695,
#  '101229': 369,
#  'id 101229': 6982,
#  'account id 101229': 4565,
#  '102036': 555,
#  'id 102036': 7168,
#  'account id 102036': 4751,
#  '101551': 451,
#  'id 101551': 7064,
#  'account id 101551': 4647,
#  '102239': 603,
#  'id 102239': 7216,
#  'account id 102239': 4799,
#  '104826': 1168,
#  'id 104826': 7769,
#  'account id 104826': 5352,
#  '102196': 597,
#  'id 102196': 7210,
#  'account id 102196': 4793,
#  '103037': 797,
#  'id 103037': 7410,
#  'account id 103037': 4993,
#  '104991': 1202,
#  'id 104991': 7803,
#  'account id 104991': 5386,
#  '102436': 657,
#  'id 102436': 7270,
#  'account id 102436': 4853,
#  '102102': 574,
#  'id 102102': 7187,
#  'account id 102102': 4770,
#  '101375': 405,
#  'id 101375': 7018,
#  'account id 101375': 4601,
#  '105081': 1229,
#  'id 105081': 7830,
#  'account id 105081': 5413,
#  '103221': 837,
#  'id 103221': 7450,
#  'account id 103221': 5033,
#  '102251': 606,
#  'id 102251': 7219,
#  'account id 102251': 4802,
#  '104635': 1124,
#  'id 104635': 7728,
#  'account id 104635': 5311,
#  '102569': 689,
#  'id 102569': 7302,
#  'account id 102569': 4885,
#  '101794': 505,
#  'id 101794': 7118,
#  'account id 101794': 4701,
#  '103098': 807,
#  'id 103098': 7420,
#  'account id 103098': 5003,
#  '103303': 858,
#  'id 103303': 7471,
#  'account id 103303': 5054,
#  '102629': 706,
#  'id 102629': 7319,
#  'account id 102629': 4902,
#  '101134': 351,
#  'id 101134': 6964,
#  'account id 101134': 4547,
#  '105104': 1239,
#  'id 105104': 7840,
#  'account id 105104': 5423,
#  '102198': 598,
#  'id 102198': 7211,
#  'account id 102198': 4794,
#  '101070': 335,
#  'id 101070': 6948,
#  'account id 101070': 4531,
#  '101716': 489,
#  'id 101716': 7102,
#  'account id 101716': 4685,
#  '104758': 1149,
#  'id 104758': 7753,
#  'account id 104758': 5336,
#  '101101': 343,
#  'id 101101': 6956,
#  'account id 101101': 4539,
#  '104514': 1091,
#  'id 104514': 7695,
#  'account id 104514': 5278,
#  '101201': 366,
#  'id 101201': 6979,
#  'account id 101201': 4562,
#  '102412': 649,
#  'id 102412': 7262,
#  'account id 102412': 4845,
#  '104719': 1137,
#  'id 104719': 7741,
#  'account id 104719': 5324,
#  '104996': 1204,
#  'id 104996': 7805,
#  'account id 104996': 5388,
#  '101289': 384,
#  'id 101289': 6997,
#  'account id 101289': 4580,
#  '103229': 840,
#  'id 103229': 7453,
#  'account id 103229': 5036,
#  '102721': 728,
#  'id 102721': 7341,
#  'account id 102721': 4924,
#  '102422': 651,
#  'id 102422': 7264,
#  'account id 102422': 4847,
#  '101286': 383,
#  'id 101286': 6996,
#  'account id 101286': 4579,
#  '103159': 825,
#  'id 103159': 7438,
#  'account id 103159': 5021,
#  '104116': 1014,
#  'id 104116': 7618,
#  'account id 104116': 5201,
#  '101522': 443,
#  'id 101522': 7056,
#  'account id 101522': 4639,
#  '101613': 463,
#  'id 101613': 7076,
#  'account id 101613': 4659,
#  '101230': 370,
#  'id 101230': 6983,
#  'account id 101230': 4566,
#  '103502': 892,
#  'id 103502': 7505,
#  'account id 103502': 5088,
#  '103479': 886,
#  'id 103479': 7499,
#  'account id 103479': 5082,
#  '101994': 543,
#  'id 101994': 7156,
#  'account id 101994': 4739,
#  '101185': 363,
#  'id 101185': 6976,
#  'account id 101185': 4559,
#  '104518': 1092,
#  'id 104518': 7696,
#  'account id 104518': 5279,
#  '105079': 1227,
#  'id 105079': 7828,
#  'account id 105079': 5411,
#  '102660': 713,
#  'id 102660': 7326,
#  'account id 102660': 4909,
#  '102395': 641,
#  'id 102395': 7254,
#  'account id 102395': 4837,
#  '103634': 913,
#  'id 103634': 7526,
#  'account id 103634': 5109,
#  '103030': 794,
#  'id 103030': 7407,
#  'account id 103030': 4990,
#  '102566': 688,
#  'id 102566': 7301,
#  'account id 102566': 4884,
#  '103111': 813,
#  'id 103111': 7426,
#  'account id 103111': 5009,
#  '102894': 765,
#  'id 102894': 7378,
#  'account id 102894': 4961,
#  '101949': 537,
#  'id 101949': 7150,
#  'account id 101949': 4733,
#  '103762': 943,
#  'id 103762': 7556,
#  'account id 103762': 5139,
#  '104927': 1188,
#  'id 104927': 7789,
#  'account id 104927': 5372,
#  '103540': 897,
#  'id 103540': 7510,
#  'account id 103540': 5093,
#  '103923': 978,
#  'id 103923': 7588,
#  'account id 103923': 5171,
#  '101923': 530,
#  'id 101923': 7143,
#  'account id 101923': 4726,
#  '101155': 353,
#  'id 101155': 6966,
#  'account id 101155': 4549,
#  '102388': 639,
#  'id 102388': 7252,
#  'account id 102388': 4835,
#  '102332': 624,
#  'id 102332': 7237,
#  'account id 102332': 4820,
#  '104300': 1048,
#  'id 104300': 7652,
#  'account id 104300': 5235,
#  '103006': 788,
#  'id 103006': 7401,
#  'account id 103006': 4984,
#  '103975': 988,
#  'id 103975': 7598,
#  'account id 103975': 5181,
#  '102857': 755,
#  'id 102857': 7368,
#  'account id 102857': 4951,
#  '101266': 378,
#  'id 101266': 6991,
#  'account id 101266': 4574,
#  '103720': 933,
#  'id 103720': 7546,
#  'account id 103720': 5129,
#  '104546': 1099,
#  'id 104546': 7703,
#  'account id 104546': 5286,
#  '104287': 1045,
#  'id 104287': 7649,
#  'account id 104287': 5232,
#  '102352': 630,
#  'id 102352': 7243,
#  'account id 102352': 4826,
#  '101340': 389,
#  'id 101340': 7002,
#  'account id 101340': 4585,
#  '104930': 1189,
#  'id 104930': 7790,
#  'account id 104930': 5373,
#  '104074': 1007,
#  'id 104074': 7611,
#  'account id 104074': 5194,
#  '101453': 422,
#  'id 101453': 7035,
#  'account id 101453': 4618,
#  '104362': 1058,
#  'id 104362': 7662,
#  'account id 104362': 5245,
#  '103034': 795,
#  'id 103034': 7408,
#  'account id 103034': 4991,
#  '103296': 857,
#  'id 103296': 7470,
#  'account id 103296': 5053,
#  '102593': 696,
#  'id 102593': 7309,
#  'account id 102593': 4892,
#  '103872': 967,
#  'id 103872': 7577,
#  'account id 103872': 5160,
#  '102523': 679,
#  'id 102523': 7292,
#  'account id 102523': 4875,
#  '101383': 406,
#  'id 101383': 7019,
#  'account id 101383': 4602,
#  '101615': 464,
#  'id 101615': 7077,
#  'account id 101615': 4660,
#  '102079': 568,
#  'id 102079': 7181,
#  'account id 102079': 4764,
#  '103227': 839,
#  'id 103227': 7452,
#  'account id 103227': 5035,
#  '103402': 873,
#  'id 103402': 7486,
#  'account id 103402': 5069,
#  '102514': 676,
#  'id 102514': 7289,
#  'account id 102514': 4872,
#  '101059': 332,
#  'id 101059': 6945,
#  'account id 101059': 4528,
#  '103360': 868,
#  'id 103360': 7481,
#  'account id 103360': 5064,
#  '103704': 928,
#  'id 103704': 7541,
#  'account id 103704': 5124,
#  '101605': 462,
#  'id 101605': 7075,
#  'account id 101605': 4658,
#  '102962': 777,
#  'id 102962': 7390,
#  'account id 102962': 4973,
#  '104620': 1118,
#  'id 104620': 7722,
#  'account id 104620': 5305,
#  '103506': 894,
#  'id 103506': 7507,
#  'account id 103506': 5090,
#  '101706': 485,
#  'id 101706': 7098,
#  'account id 101706': 4681,
#  '104248': 1039,
#  'id 104248': 7643,
#  'account id 104248': 5226,
#  '103899': 972,
#  'id 103899': 7582,
#  'account id 103899': 5165,
#  '102776': 741,
#  'id 102776': 7354,
#  'account id 102776': 4937,
#  '101296': 386,
#  'id 101296': 6999,
#  'account id 101296': 4582,
#  '104607': 1116,
#  'id 104607': 7720,
#  'account id 104607': 5303,
#  '101124': 350,
#  'id 101124': 6963,
#  'account id 101124': 4546,
#  '101363': 397,
#  'id 101363': 7010,
#  'account id 101363': 4593,
#  '101724': 491,
#  'id 101724': 7104,
#  'account id 101724': 4687,
#  '104347': 1055,
#  'id 104347': 7659,
#  'account id 104347': 5242,
#  '103614': 910,
#  'id 103614': 7523,
#  'account id 103614': 5106,
#  '104109': 1011,
#  'id 104109': 7615,
#  'account id 104109': 5198,
#  '102966': 778,
#  'id 102966': 7391,
#  'account id 102966': 4974,
#  '104533': 1095,
#  'id 104533': 7699,
#  'account id 104533': 5282,
#  '103414': 874,
#  'id 103414': 7487,
#  'account id 103414': 5070,
#  '101730': 493,
#  'id 101730': 7106,
#  'account id 101730': 4689,
#  '104789': 1157,
#  'id 104789': 7761,
#  'account id 104789': 5344,
#  '104622': 1119,
#  'id 104622': 7723,
#  'account id 104622': 5306,
#  '101848': 518,
#  'id 101848': 7131,
#  'account id 101848': 4714,
#  '102755': 737,
#  'id 102755': 7350,
#  'account id 102755': 4933,
#  '102444': 661,
#  'id 102444': 7274,
#  'account id 102444': 4857,
#  '103756': 941,
#  'id 103756': 7554,
#  'account id 103756': 5137,
#  '104476': 1084,
#  'id 104476': 7688,
#  'account id 104476': 5271,
#  '104743': 1145,
#  'id 104743': 7749,
#  'account id 104743': 5332,
#  '101681': 478,
#  'id 101681': 7091,
#  'account id 101681': 4674,
#  '104582': 1107,
#  'id 104582': 7711,
#  'account id 104582': 5294,
#  '103335': 863,
#  'id 103335': 7476,
#  'account id 103335': 5059,
#  '102393': 640,
#  'id 102393': 7253,
#  'account id 102393': 4836,
#  '101167': 358,
#  'id 101167': 6971,
#  'account id 101167': 4554,
#  '102671': 718,
#  'id 102671': 7331,
#  'account id 102671': 4914,
#  '104950': 1192,
#  ...}

# %%
vec.shape
# Out:
# (19000, 11461)

# %%
pd.to_pickle(vec, "/home/aditya/Documents/Project1-CITI-INTERNSHIP/vec.pkl")
pd.to_pickle(vec, "/home/aditya/Documents/Project1-CITI-INTERNSHIP/dict.pkl")
