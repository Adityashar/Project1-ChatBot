# %%
import numpy as np
import pandas as pd
import os
import json
import markdown
import pickle

# %%
def new_data(data_name, directory):
    # get the name of the new dataset file
    
    DATASET_LOC = os.path.join(directory, data_name)

    # read the data file - csv, excel and json

    if data_name.endswith('.csv'):
        DATASET = pd.read_csv(DATASET_LOC)
    elif data_name.endswith('.xlx') or data_name.endswith('.xlsx'):
        DATASET = pd.read_excel(DATASET_LOC)
    elif data_name.endswith('.json'):
        DATASET = pd.DataFrame(json.load(open(DATASET_LOC, 'r')), index =[1])
    return DATASET

# %%
# This function should be triggered by a listener

data_name = "table.csv"
directory = '/home/aditya/Documents/citibot/newdata'
DATASET = new_data(data_name, directory)

# dict of columns in new data with corresponding dtypes

DATASET['Specimen No'] = DATASET['Specimen No'].astype('str')
DATASET.columns =["column " + str(i) for i, column in enumerate(DATASET.columns)] 
DATASET.columns =[column.replace(" ", "_") for column in DATASET.columns] 

FEATURES = {col: DATASET[col].dtype for col in DATASET}
DATASET.head()
# Out:
#     column_0  column_1  column_2  column_3  column_4  column_5  column_6
# 0  SPECIMEN1       1.0     300.0      36.0      1.25        10    0.0027
# 1  SPECIMEN2       2.0     450.0      48.0      1.25        10    0.0029
# 2  SPECIMEN3       5.0     600.0      64.0      1.25        10    0.0022
# 3  SPECIMEN4       1.0     300.0      48.0      1.66        20    0.0008
# 4  SPECIMEN5       2.0     450.0      64.0      1.66        20    0.0012

# %%
# List all the possible entities 
def get_entities(threshold_value):
    PRIMARY_KEY = []
    ENTITIES = {}

    for col in FEATURES.keys():
        if (DATASET[col].unique().shape[0] == DATASET.shape[0]) and (FEATURES[col] == 'O' or FEATURES[col] == 'int64'):           
            PRIMARY_KEY.append(col)                                             # Make this the PRIMARY KEY
            ENTITIES[col] = DATASET[col].unique()[:threshold_value].tolist()

        elif DATASET[col].unique().shape[0] > threshold_value and (FEATURES[col] == 'O' or FEATURES[col] == 'int64'):
            ENTITIES[col] = DATASET[col].unique()[:threshold_value].tolist()

        elif FEATURES[col] == 'O' or FEATURES[col] == 'int64':
            ENTITIES[col] = DATASET[col].unique().tolist()
            
    return ENTITIES, PRIMARY_KEY

threshold_value = 20
ENTITIES, PRIMARY_KEY = get_entities(threshold_value)
ENTITIES
# Out:
# {'column_0': ['SPECIMEN1',
#   'SPECIMEN2',
#   'SPECIMEN3',
#   'SPECIMEN4',
#   'SPECIMEN5',
#   'SPECIMEN6',
#   'SPECIMEN7',
#   'SPECIMEN8',
#   'SPECIMEN9',
#   'SPECIMEN10',
#   'SPECIMEN11',
#   'SPECIMEN12',
#   'SPECIMEN13',
#   'SPECIMEN14',
#   'SPECIMEN15',
#   'SPECIMEN16',
#   'SPECIMEN17',
#   'SPECIMEN18',
#   'SPECIMEN19',
#   'SPECIMEN20'],
#  'column_5': [10, 20, 30]}

# %%
# def add_ques1(intent, entity , values):
#     questions = []
    
#     for value in values:
#         questions.append("What is the {} for transaction with [{}]({})".format(intent,value,entity))
#         questions.append("Give me the {} details about agreement with [{}]({})".format(intent,value,entity))
#         questions.append("Tell me the {} for the [{}]({})".format(intent, value, entity))
#         questions.append("Can you show me the {} for [{}] ({})".format(intent , value, entity))
#         questions.append("I request you to provide me the {} made with [{}] ({})".format(intent , value, entity))
#         questions.append("Could you please give me the {} insights regarding concurrence with [{}]({})".format(intent,value,entity))
#         questions.append("For the {} disclose to me the {}".format(intent,value,entity))
#         questions.append("Please check the {} of [{}] ({})".format(intent , value, entity))
#         questions.append("Brief me about the {} for the accord with [{}]({})".format(intent,value,entity))
#         questions.append("Please show me the {} for transaction with [{}] ({})".format(intent , value, entity))
    
#     return questions



# def add_ques2(intent, entity1 , values1, entity2 , values2):
#     questions = []
    
#     for value1 in values1:
#         for value2 in values2:
#             questions.append("What is the {} that [{}]({}) has to pay to [{}]({})?".format(intent,value1,entity1,value2,entity2))
#             questions.append("Give me details about {} for transaction with [{}]({}) for agreement [{}]({})".format(intent,value1,entity1,value2,entity2))
#             questions.append("Brief us about the {} for the agreement of [{}]({}) for transaction with [{}]({})".format(intent,value1,entity1,value2,entity2))     
#             questions.append("For agreement with [{}]({}) give me the subtleties of the {} from [{}]({})".format(value2,entity2, intent, value1,entity1))
#             questions.append("For [{}]({}) with id [{}]({}) tell me the {}.".format(value1, entity1, value2, entity2, intent))
#             questions.append("for the concurrence with [{}]({}) give me report of {} from [{}]({})".format(value1,entity1, intent, value2, entity2))
#     return questions

    
# def get_questions(intent,entities):
#     questions = []
    
#     for entity,value in entities.items():
#         questions.extend(add_ques1(intent,entity,value))
    
#     for entity1,value1 in entities.items():
#         for entity2,value2 in entities.items():
#             if entity1 != entity2:
#                 questions.extend(add_ques2(intent,entity1,value1,entity2,value2))

#     return questions

# intents = ["payment status", "payment date"]
# entities = {"Legal_name":["citi","pity"], "account_id":[1022,1033]}

# q = get_questions(intents[0],entities)
# q

# %%
# For query generation, any number of previously determined entities (values) can be used.
# For each intent, what should differ between the different sets of queries is the meaning the latter conveys.
# For eg if we have an intent "Cost", it should have questions like :
# what is the cost {intent} for entity_1{value} ?
# Since we have to use the intent / Feature name as a part of the query itself, an important thing to conside is 
# that the feature names should be simple and directly convey their purpose
# For eg, feature name can be "cost" but if the feature name is "cost per head" then we the issue is that
# the intent name wont be the same as the feature name, once this happens we'll have to extract the real intent 
# from the feature names which is not possible to do right now.

# def get_questions(intent):
#     questions = []
#     questions.append("what is {} for [{}]({})".format(intent, value, entity))
#     questions.append("Tell me something about {} with ".format(intent))
#     questions.append("Give me information about {} for the ".format(intent))
    
#     return questions

# Dict of intents having a list of questions as their values.
from getQuestions import get_questions

INTENTS = {col:get_questions(col, ENTITIES) for col in FEATURES.keys()}
INTENTS
# Out:
# {'column_0': ['What is the column_0 for transaction with [SPECIMEN1](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN1](column_0)',
#   'Tell me the column_0 for the [SPECIMEN1](column_0)',
#   'Can you show me the column_0 for [SPECIMEN1] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN1] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN1](column_0)',
#   'For the column_0 disclose to me the SPECIMEN1',
#   'Please check the column_0 of [SPECIMEN1] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN1](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN1] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN2](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN2](column_0)',
#   'Tell me the column_0 for the [SPECIMEN2](column_0)',
#   'Can you show me the column_0 for [SPECIMEN2] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN2] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN2](column_0)',
#   'For the column_0 disclose to me the SPECIMEN2',
#   'Please check the column_0 of [SPECIMEN2] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN2](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN2] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN3](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN3](column_0)',
#   'Tell me the column_0 for the [SPECIMEN3](column_0)',
#   'Can you show me the column_0 for [SPECIMEN3] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN3] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN3](column_0)',
#   'For the column_0 disclose to me the SPECIMEN3',
#   'Please check the column_0 of [SPECIMEN3] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN3](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN3] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN4](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN4](column_0)',
#   'Tell me the column_0 for the [SPECIMEN4](column_0)',
#   'Can you show me the column_0 for [SPECIMEN4] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN4] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN4](column_0)',
#   'For the column_0 disclose to me the SPECIMEN4',
#   'Please check the column_0 of [SPECIMEN4] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN4](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN4] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN5](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN5](column_0)',
#   'Tell me the column_0 for the [SPECIMEN5](column_0)',
#   'Can you show me the column_0 for [SPECIMEN5] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN5] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN5](column_0)',
#   'For the column_0 disclose to me the SPECIMEN5',
#   'Please check the column_0 of [SPECIMEN5] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN5](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN5] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN6](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN6](column_0)',
#   'Tell me the column_0 for the [SPECIMEN6](column_0)',
#   'Can you show me the column_0 for [SPECIMEN6] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN6] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN6](column_0)',
#   'For the column_0 disclose to me the SPECIMEN6',
#   'Please check the column_0 of [SPECIMEN6] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN6](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN6] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN7](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN7](column_0)',
#   'Tell me the column_0 for the [SPECIMEN7](column_0)',
#   'Can you show me the column_0 for [SPECIMEN7] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN7] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN7](column_0)',
#   'For the column_0 disclose to me the SPECIMEN7',
#   'Please check the column_0 of [SPECIMEN7] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN7](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN7] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN8](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN8](column_0)',
#   'Tell me the column_0 for the [SPECIMEN8](column_0)',
#   'Can you show me the column_0 for [SPECIMEN8] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN8] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN8](column_0)',
#   'For the column_0 disclose to me the SPECIMEN8',
#   'Please check the column_0 of [SPECIMEN8] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN8](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN8] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN9](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN9](column_0)',
#   'Tell me the column_0 for the [SPECIMEN9](column_0)',
#   'Can you show me the column_0 for [SPECIMEN9] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN9] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN9](column_0)',
#   'For the column_0 disclose to me the SPECIMEN9',
#   'Please check the column_0 of [SPECIMEN9] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN9](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN9] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN10](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN10](column_0)',
#   'Tell me the column_0 for the [SPECIMEN10](column_0)',
#   'Can you show me the column_0 for [SPECIMEN10] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN10] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN10](column_0)',
#   'For the column_0 disclose to me the SPECIMEN10',
#   'Please check the column_0 of [SPECIMEN10] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN10](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN10] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN11](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN11](column_0)',
#   'Tell me the column_0 for the [SPECIMEN11](column_0)',
#   'Can you show me the column_0 for [SPECIMEN11] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN11] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN11](column_0)',
#   'For the column_0 disclose to me the SPECIMEN11',
#   'Please check the column_0 of [SPECIMEN11] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN11](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN11] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN12](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN12](column_0)',
#   'Tell me the column_0 for the [SPECIMEN12](column_0)',
#   'Can you show me the column_0 for [SPECIMEN12] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN12] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN12](column_0)',
#   'For the column_0 disclose to me the SPECIMEN12',
#   'Please check the column_0 of [SPECIMEN12] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN12](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN12] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN13](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN13](column_0)',
#   'Tell me the column_0 for the [SPECIMEN13](column_0)',
#   'Can you show me the column_0 for [SPECIMEN13] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN13] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN13](column_0)',
#   'For the column_0 disclose to me the SPECIMEN13',
#   'Please check the column_0 of [SPECIMEN13] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN13](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN13] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN14](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN14](column_0)',
#   'Tell me the column_0 for the [SPECIMEN14](column_0)',
#   'Can you show me the column_0 for [SPECIMEN14] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN14] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN14](column_0)',
#   'For the column_0 disclose to me the SPECIMEN14',
#   'Please check the column_0 of [SPECIMEN14] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN14](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN14] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN15](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN15](column_0)',
#   'Tell me the column_0 for the [SPECIMEN15](column_0)',
#   'Can you show me the column_0 for [SPECIMEN15] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN15] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN15](column_0)',
#   'For the column_0 disclose to me the SPECIMEN15',
#   'Please check the column_0 of [SPECIMEN15] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN15](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN15] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN16](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN16](column_0)',
#   'Tell me the column_0 for the [SPECIMEN16](column_0)',
#   'Can you show me the column_0 for [SPECIMEN16] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN16] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN16](column_0)',
#   'For the column_0 disclose to me the SPECIMEN16',
#   'Please check the column_0 of [SPECIMEN16] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN16](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN16] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN17](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN17](column_0)',
#   'Tell me the column_0 for the [SPECIMEN17](column_0)',
#   'Can you show me the column_0 for [SPECIMEN17] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN17] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN17](column_0)',
#   'For the column_0 disclose to me the SPECIMEN17',
#   'Please check the column_0 of [SPECIMEN17] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN17](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN17] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN18](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN18](column_0)',
#   'Tell me the column_0 for the [SPECIMEN18](column_0)',
#   'Can you show me the column_0 for [SPECIMEN18] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN18] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN18](column_0)',
#   'For the column_0 disclose to me the SPECIMEN18',
#   'Please check the column_0 of [SPECIMEN18] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN18](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN18] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN19](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN19](column_0)',
#   'Tell me the column_0 for the [SPECIMEN19](column_0)',
#   'Can you show me the column_0 for [SPECIMEN19] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN19] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN19](column_0)',
#   'For the column_0 disclose to me the SPECIMEN19',
#   'Please check the column_0 of [SPECIMEN19] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN19](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN19] (column_0)',
#   'What is the column_0 for transaction with [SPECIMEN20](column_0)',
#   'Give me the column_0 details about agreement with [SPECIMEN20](column_0)',
#   'Tell me the column_0 for the [SPECIMEN20](column_0)',
#   'Can you show me the column_0 for [SPECIMEN20] (column_0)',
#   'I request you to provide me the column_0 made with [SPECIMEN20] (column_0)',
#   'Could you please give me the column_0 insights regarding concurrence with [SPECIMEN20](column_0)',
#   'For the column_0 disclose to me the SPECIMEN20',
#   'Please check the column_0 of [SPECIMEN20] (column_0)',
#   'Brief me about the column_0 for the accord with [SPECIMEN20](column_0)',
#   'Please show me the column_0 for transaction with [SPECIMEN20] (column_0)',
#   'What is the column_0 for transaction with [10](column_5)',
#   'Give me the column_0 details about agreement with [10](column_5)',
#   'Tell me the column_0 for the [10](column_5)',
#   'Can you show me the column_0 for [10] (column_5)',
#   'I request you to provide me the column_0 made with [10] (column_5)',
#   'Could you please give me the column_0 insights regarding concurrence with [10](column_5)',
#   'For the column_0 disclose to me the 10',
#   'Please check the column_0 of [10] (column_5)',
#   'Brief me about the column_0 for the accord with [10](column_5)',
#   'Please show me the column_0 for transaction with [10] (column_5)',
#   'What is the column_0 for transaction with [20](column_5)',
#   'Give me the column_0 details about agreement with [20](column_5)',
#   'Tell me the column_0 for the [20](column_5)',
#   'Can you show me the column_0 for [20] (column_5)',
#   'I request you to provide me the column_0 made with [20] (column_5)',
#   'Could you please give me the column_0 insights regarding concurrence with [20](column_5)',
#   'For the column_0 disclose to me the 20',
#   'Please check the column_0 of [20] (column_5)',
#   'Brief me about the column_0 for the accord with [20](column_5)',
#   'Please show me the column_0 for transaction with [20] (column_5)',
#   'What is the column_0 for transaction with [30](column_5)',
#   'Give me the column_0 details about agreement with [30](column_5)',
#   'Tell me the column_0 for the [30](column_5)',
#   'Can you show me the column_0 for [30] (column_5)',
#   'I request you to provide me the column_0 made with [30] (column_5)',
#   'Could you please give me the column_0 insights regarding concurrence with [30](column_5)',
#   'For the column_0 disclose to me the 30',
#   'Please check the column_0 of [30] (column_5)',
#   'Brief me about the column_0 for the accord with [30](column_5)',
#   'Please show me the column_0 for transaction with [30] (column_5)',
#   'What is the column_0 that [SPECIMEN1](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN1](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN1](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN1](column_0)',
#   'For [SPECIMEN1](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN1](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN1](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN1](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN1](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN1](column_0)',
#   'For [SPECIMEN1](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN1](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN1](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN1](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN1](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN1](column_0)',
#   'For [SPECIMEN1](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN1](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN2](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN2](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN2](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN2](column_0)',
#   'For [SPECIMEN2](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN2](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN2](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN2](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN2](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN2](column_0)',
#   'For [SPECIMEN2](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN2](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN2](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN2](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN2](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN2](column_0)',
#   'For [SPECIMEN2](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN2](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN3](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN3](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN3](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN3](column_0)',
#   'For [SPECIMEN3](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN3](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN3](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN3](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN3](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN3](column_0)',
#   'For [SPECIMEN3](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN3](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN3](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN3](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN3](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN3](column_0)',
#   'For [SPECIMEN3](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN3](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN4](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN4](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN4](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN4](column_0)',
#   'For [SPECIMEN4](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN4](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN4](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN4](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN4](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN4](column_0)',
#   'For [SPECIMEN4](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN4](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN4](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN4](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN4](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN4](column_0)',
#   'For [SPECIMEN4](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN4](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN5](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN5](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN5](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN5](column_0)',
#   'For [SPECIMEN5](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN5](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN5](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN5](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN5](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN5](column_0)',
#   'For [SPECIMEN5](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN5](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN5](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN5](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN5](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN5](column_0)',
#   'For [SPECIMEN5](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN5](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN6](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN6](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN6](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN6](column_0)',
#   'For [SPECIMEN6](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN6](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN6](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN6](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN6](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN6](column_0)',
#   'For [SPECIMEN6](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN6](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN6](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN6](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN6](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN6](column_0)',
#   'For [SPECIMEN6](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN6](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN7](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN7](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN7](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN7](column_0)',
#   'For [SPECIMEN7](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN7](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN7](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN7](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN7](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN7](column_0)',
#   'For [SPECIMEN7](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN7](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN7](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN7](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN7](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN7](column_0)',
#   'For [SPECIMEN7](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN7](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN8](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN8](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN8](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN8](column_0)',
#   'For [SPECIMEN8](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN8](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN8](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN8](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN8](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN8](column_0)',
#   'For [SPECIMEN8](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN8](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN8](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN8](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN8](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN8](column_0)',
#   'For [SPECIMEN8](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN8](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN9](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN9](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN9](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN9](column_0)',
#   'For [SPECIMEN9](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN9](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN9](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN9](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN9](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN9](column_0)',
#   'For [SPECIMEN9](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN9](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN9](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN9](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN9](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN9](column_0)',
#   'For [SPECIMEN9](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN9](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN10](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN10](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN10](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN10](column_0)',
#   'For [SPECIMEN10](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN10](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN10](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN10](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN10](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN10](column_0)',
#   'For [SPECIMEN10](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN10](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN10](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN10](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN10](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN10](column_0)',
#   'For [SPECIMEN10](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN10](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN11](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN11](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN11](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN11](column_0)',
#   'For [SPECIMEN11](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN11](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN11](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN11](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN11](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN11](column_0)',
#   'For [SPECIMEN11](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN11](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN11](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN11](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN11](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN11](column_0)',
#   'For [SPECIMEN11](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN11](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN12](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN12](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN12](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN12](column_0)',
#   'For [SPECIMEN12](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN12](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN12](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN12](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN12](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN12](column_0)',
#   'For [SPECIMEN12](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN12](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN12](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN12](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN12](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN12](column_0)',
#   'For [SPECIMEN12](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN12](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN13](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN13](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN13](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN13](column_0)',
#   'For [SPECIMEN13](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN13](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN13](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN13](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN13](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN13](column_0)',
#   'For [SPECIMEN13](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN13](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN13](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN13](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN13](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN13](column_0)',
#   'For [SPECIMEN13](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN13](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN14](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN14](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN14](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN14](column_0)',
#   'For [SPECIMEN14](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN14](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN14](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN14](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN14](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN14](column_0)',
#   'For [SPECIMEN14](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN14](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN14](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN14](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN14](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN14](column_0)',
#   'For [SPECIMEN14](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN14](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN15](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN15](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN15](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN15](column_0)',
#   'For [SPECIMEN15](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN15](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN15](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN15](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN15](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN15](column_0)',
#   'For [SPECIMEN15](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN15](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN15](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN15](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN15](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN15](column_0)',
#   'For [SPECIMEN15](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN15](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN16](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN16](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN16](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN16](column_0)',
#   'For [SPECIMEN16](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN16](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN16](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN16](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN16](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN16](column_0)',
#   'For [SPECIMEN16](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN16](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN16](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN16](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN16](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN16](column_0)',
#   'For [SPECIMEN16](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN16](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN17](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN17](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN17](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN17](column_0)',
#   'For [SPECIMEN17](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN17](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN17](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN17](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN17](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN17](column_0)',
#   'For [SPECIMEN17](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN17](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN17](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN17](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN17](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN17](column_0)',
#   'For [SPECIMEN17](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN17](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN18](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN18](column_0) for agreement [10](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN18](column_0) for transaction with [10](column_5)',
#   'For agreement with [10](column_5) give me the subtleties of the column_0 from [SPECIMEN18](column_0)',
#   'For [SPECIMEN18](column_0) with id [10](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN18](column_0) give me report of column_0 from [10](column_5)',
#   'What is the column_0 that [SPECIMEN18](column_0) has to pay to [20](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN18](column_0) for agreement [20](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN18](column_0) for transaction with [20](column_5)',
#   'For agreement with [20](column_5) give me the subtleties of the column_0 from [SPECIMEN18](column_0)',
#   'For [SPECIMEN18](column_0) with id [20](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN18](column_0) give me report of column_0 from [20](column_5)',
#   'What is the column_0 that [SPECIMEN18](column_0) has to pay to [30](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN18](column_0) for agreement [30](column_5)',
#   'Brief us about the column_0 for the agreement of [SPECIMEN18](column_0) for transaction with [30](column_5)',
#   'For agreement with [30](column_5) give me the subtleties of the column_0 from [SPECIMEN18](column_0)',
#   'For [SPECIMEN18](column_0) with id [30](column_5) tell me the column_0.',
#   'for the concurrence with [SPECIMEN18](column_0) give me report of column_0 from [30](column_5)',
#   'What is the column_0 that [SPECIMEN19](column_0) has to pay to [10](column_5)?',
#   'Give me details about column_0 for transaction with [SPECIMEN19](column_0) for agreement [10](column_5)',
# ...
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN13](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN14](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN14](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN14](column_0)',
#   'For agreement with [SPECIMEN14](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN14](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN14](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN15](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN15](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN15](column_0)',
#   'For agreement with [SPECIMEN15](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN15](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN15](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN16](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN16](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN16](column_0)',
#   'For agreement with [SPECIMEN16](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN16](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN16](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN17](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN17](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN17](column_0)',
#   'For agreement with [SPECIMEN17](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN17](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN17](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN18](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN18](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN18](column_0)',
#   'For agreement with [SPECIMEN18](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN18](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN18](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN19](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN19](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN19](column_0)',
#   'For agreement with [SPECIMEN19](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN19](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN19](column_0)',
#   'What is the column_6 that [20](column_5) has to pay to [SPECIMEN20](column_0)?',
#   'Give me details about column_6 for transaction with [20](column_5) for agreement [SPECIMEN20](column_0)',
#   'Brief us about the column_6 for the agreement of [20](column_5) for transaction with [SPECIMEN20](column_0)',
#   'For agreement with [SPECIMEN20](column_0) give me the subtleties of the column_6 from [20](column_5)',
#   'For [20](column_5) with id [SPECIMEN20](column_0) tell me the column_6.',
#   'for the concurrence with [20](column_5) give me report of column_6 from [SPECIMEN20](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN1](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN1](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN1](column_0)',
#   'For agreement with [SPECIMEN1](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN1](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN1](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN2](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN2](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN2](column_0)',
#   'For agreement with [SPECIMEN2](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN2](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN2](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN3](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN3](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN3](column_0)',
#   'For agreement with [SPECIMEN3](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN3](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN3](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN4](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN4](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN4](column_0)',
#   'For agreement with [SPECIMEN4](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN4](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN4](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN5](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN5](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN5](column_0)',
#   'For agreement with [SPECIMEN5](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN5](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN5](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN6](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN6](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN6](column_0)',
#   'For agreement with [SPECIMEN6](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN6](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN6](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN7](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN7](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN7](column_0)',
#   'For agreement with [SPECIMEN7](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN7](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN7](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN8](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN8](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN8](column_0)',
#   'For agreement with [SPECIMEN8](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN8](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN8](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN9](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN9](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN9](column_0)',
#   'For agreement with [SPECIMEN9](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN9](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN9](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN10](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN10](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN10](column_0)',
#   'For agreement with [SPECIMEN10](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN10](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN10](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN11](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN11](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN11](column_0)',
#   'For agreement with [SPECIMEN11](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN11](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN11](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN12](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN12](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN12](column_0)',
#   'For agreement with [SPECIMEN12](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN12](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN12](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN13](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN13](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN13](column_0)',
#   'For agreement with [SPECIMEN13](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN13](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN13](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN14](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN14](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN14](column_0)',
#   'For agreement with [SPECIMEN14](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN14](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN14](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN15](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN15](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN15](column_0)',
#   'For agreement with [SPECIMEN15](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN15](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN15](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN16](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN16](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN16](column_0)',
#   'For agreement with [SPECIMEN16](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN16](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN16](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN17](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN17](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN17](column_0)',
#   'For agreement with [SPECIMEN17](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN17](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN17](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN18](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN18](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN18](column_0)',
#   'For agreement with [SPECIMEN18](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN18](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN18](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN19](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN19](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN19](column_0)',
#   'For agreement with [SPECIMEN19](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN19](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN19](column_0)',
#   'What is the column_6 that [30](column_5) has to pay to [SPECIMEN20](column_0)?',
#   'Give me details about column_6 for transaction with [30](column_5) for agreement [SPECIMEN20](column_0)',
#   'Brief us about the column_6 for the agreement of [30](column_5) for transaction with [SPECIMEN20](column_0)',
#   'For agreement with [SPECIMEN20](column_0) give me the subtleties of the column_6 from [30](column_5)',
#   'For [30](column_5) with id [SPECIMEN20](column_0) tell me the column_6.',
#   'for the concurrence with [30](column_5) give me report of column_6 from [SPECIMEN20](column_0)']}

# %%
# making a dictionary of tables with corresponding intents for query based retrieval

table = os.path.splitext(data_name)[0]

if 'dict.pkl' not in os.listdir('/home/aditya/Documents/citibot/data'):
    information_table = {}
else:
    information_table = pickle.load(open('/home/aditya/Documents/citibot/data/dict.pkl', 'rb'))

information_table[table] = list(INTENTS.keys())
pickle.dump(information_table, open('/home/aditya/Documents/citibot/data/dict.pkl', 'wb'))

information_table
# Out:
# {'table': ['column_0',
#   'column_1',
#   'column_2',
#   'column_3',
#   'column_4',
#   'column_5',
#   'column_6']}

# %%
# the current nlu.md file has the following information : (1)intents, (2)lookup, (3)synonyms
# created three functions to update each of the these sections respectively
# optimisation for future instead of writing, just append new data


def synonyms_to_md(data_md, entity_dict):
    data = []
    for entity in entity_dict.keys():
        if FEATURES[entity] == 'int64' or entity in PRIMARY_KEY:
            continue
            
        # Now the only entities left are character dtype with limited uniques
        # For each value in entity add synonyms
        
        for val in entity_dict[entity]:
            string = " synonym:{}\n".format(val)
            synonyms = [val.lower(), val.upper(), val.title()]
            for sys in synonyms:
                string += "- {}\n".format(sys)
            string += "\n"
            data.append(string)
    
    data_md += data
    return data_md

# lookup should not include primary_key entity, integer entities

def lookups_to_md(data_md, entity_dict):
    data = []
    for entity in entity_dict.keys():
        string_ent = " lookup:{}\n".format(entity)
        
        if FEATURES[entity] == 'int64' or entity in PRIMARY_KEY:
            continue
            
        for val in entity_dict[entity]:
            string_ent += "- {}\n".format(val)
        string_ent += "\n"
        data.append(string_ent)
    
    data_md += data
    return data_md

def intents_to_md(data_md, intent_dict):
    data_md[-1] = data_md[-1] + '\n'
    data = []
    for intent in intent_dict.keys():
        string_intent = " intent:{}\n".format(intent)
        for ques in intent_dict[intent]:
            string_intent += "- {}\n".format(ques)
        string_intent += "\n"
        data.append(string_intent)
    
    data_md += data
#     print(data)
    return data_md

nlu = open('/home/aditya/Documents/citibot/newdata/nlu.md', 'r')
s=nlu.read().split('##')

nlu_intent = intents_to_md(s, INTENTS)
nlu_lookup = lookups_to_md(nlu_intent, ENTITIES)
# nlu_synonyms = synonyms_to_md(nlu_lookup, ENTITIES)

new_nlu = '##'.join(nlu_lookup)

f = open("demofile2.md", "w")
f.write(new_nlu)
f.close()

# %%
# the current stories.md file has storylines with respect to a classified intent
# For the dynamic addition of data, contextual storylines cannot be added due to their increased complexity
# name : ## {intent} path

def new_stories(story, intent_dict):
    story[-1] = story[-1] + '\n'

    data = []
    actions = []
    for intent in intent_dict:
        action = "action_{}".format(intent)
        string =" {} path 1\n* {}\n  - {}\n\n".format(intent, intent, action)
        data.append(string)
        actions.append(action)
        
    story += data
    return story, actions
    
story = open('/home/aditya/Documents/citibot/newdata/stories.md', 'r')
s=story.read().split('##')

story_text, Actions = new_stories(s, INTENTS)
new_story = '##'.join(story_text)

f = open("story.md", "w")
f.write(new_story)
f.close()

# %%
# updating the actions file by addition of new actions based on an intent
# Each of the new intent is mapped to an action which will be triggered once the latter intent is predicted
# First open the given actions.py file in append mode, add the template text and voila new action is updated !
text = """

class {}(Action):

    def name(self) -> Text:
        return "{}"

    def run(self, dispatcher: CollectingDispatcher,
            tracker: Tracker,
            domain: Dict[Text, Any]) -> List[Dict[Text, Any]]:

        try:
            entities = tracker.latest_message['entities']
            table = get_table(tracker.latest_message['intent'])
            if(len(entities) == 0):
                dispatcher.utter_message(template = '{}')
                return []

            records = record_finder(entities)

            if(records.empty):
                raise ValueError("No record for this query !!!")
    
            print(records)
            dispatcher.utter_message(text="{}")
            return []

        except:
            dispatcher.utter_message(text = str(sys.exc_info()[1]))
            return []
"""


def add_action(Action, file):
    utter = []
    for action in Action[:2]:
        utterance = "utter" + action[6:]
        class_name = action.replace("_", "")
        utter.append(utterance)
        template = text.format(class_name, action, utterance, "its working for ")
        file.write(template)
#         print(template)
    
    return utter

current_actions = open('/home/aditya/Documents/ipynb/actions.py', 'a', encoding = 'utf-8')
utterances = add_action(Actions, current_actions)
print(utterances)
file.close()
# Out:
# ['utter_column_0', 'utter_column_1']

# %%
# updating the domain.yml file
# it contains a list of intents, actions, responses, entities, slots

def update_domain(intents, actions, entities, responses, data):
    
    # update intent list
    pointer_intent = data.find("intents:")
    string = ""
    for intent in intents:
        string += "  - {}\n".format(intent)
    data = data[:pointer_intent+9] + string + data[pointer_intent+9:]
    
    # update actions list 
    pointer_actions = data.find("actions:")
    string = ""
    for action in actions[:2]:
        string += "  - {}\n".format(action)
    data = data[:pointer_actions+9] + string + data[pointer_actions+9:]
    
    # update entity list
    pointer_ent = data.find("entities:")
    string = ""
    for entity in entities:
        string += "  - {}\n".format(entity)
    data = data[:pointer_ent+10] + string + data[pointer_ent+10:]
    
    # update slot list
#     pointer_ent = data.find("slots:")
#     string = ""
#     for entity in entities:
#         string += "  - {}\n".format(entity)
#     data = data[:pointer_ent+10] + string + data[pointer_ent+10:]
    # update response list
#     pointer_ent = data.find("responses:")
#     string = ""
#     for entity in entities:
#         string += "  - {}\n".format(entity)
#     data = data[:pointer_ent+10] + string + data[pointer_ent+10:]
    
    return data

domain = open('/home/aditya/Documents/ipynb/domain.yml', 'r').read()
new_domain = update_domain(list(INTENTS.keys()), Actions, list(ENTITIES.keys()), utterances, domain)
# print(domain[domain.find("actions:"): domain.find("actions:")+9] + "jj\n" +domain[domain.find("actions:") + 9:])
# print(domain)
f = open("domain.yml", "w")
f.write(new_domain)
f.close()

# %%
text = """

class ActionPayment(Action):

    def name(self) -> Text:
        return {}

    def run(self, dispatcher: CollectingDispatcher,
            tracker: Tracker,
            domain: Dict[Text, Any]) -> List[Dict[Text, Any]]:

        try:
            entities = tracker.latest_message['entities']
            table = get_table(tracker.latest_message['intent'])
            if(len(entities) == 0):
                dispatcher.utter_message(template = {})
                return []

            records = record_finder(entities)

            if(records.empty):
                raise ValueError("No record for this query !!!")
    
            print(records)
            dispatcher.utter_message(text={} +records[{}].item())# {}  {}".format(PS, LE))
            return [{}]

        except:
            dispatcher.utter_message(text = str(sys.exc_info()[1]))
            return []
"""


file = open('/home/aditya/Documents/ipynb/actions.py', 'a', encoding = 'utf-8')
file.write(text)
file.close()

mdf = open('/home/aditya/Documents/citibot/newdata/nlu.md', 'r')
# markdown.markdown(mdf.read())
s=mdf.read().split('##')

h, p = "heyaaaa", "how"
string = ""

string1 = " intent:{}\n".format(h)
string1 += "- {}\n".format(p)
string1 += "\n"

string2 = " intent:{}\n".format(p)
string2 += "- {}\n".format(h)
string2 += "\n"
ss= []
ss.append(string1)
ss.append(string2)
print(ss)
v = '##'.join([string, string1, string2])

s[-1] = s[-1] + '\n'
s += ss
print(s)
v = '##'.join(s)

text = "adbc {}"
x=1
t = text.format("8")
print(t)
text = "action_intent"
"utter"+text[6:]
